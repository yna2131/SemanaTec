# %% [markdown]
# <a href="https://colab.research.google.com/github/yna2131/SemanaTec/blob/main/actividad05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Actividad - Librería Pandas**

# %% [markdown]
# *   **Nombre:** Yuna Chung
# *   **Matrícula:** A01709043

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Entregar:** Archivo PDF de la actividad, así como el archivo .ipynb en tu repositorio. **Nota:** Recuerda habrá una penalización de 50 puntos si la actividad fue entregada fuera de la fecha límite.

# %% [markdown]
# 1.    Subir el archivo `netflix_titles.csv` que se encuentra en el repositorio de la clase y cargalos en un `Dataframe`.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-ed8579b8-a416-422e-ad83-4d4c9f2e5cde" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed8579b8-a416-422e-ad83-4d4c9f2e5cde">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('netflix_titles.csv')

# %% [markdown]
# 2.   Desplegar las primeras 5 líneas del `DataFrame`.

# %%
df.head(5)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %% [markdown]
# 3.   Implementa una función que despliegue el primer renglón de un `DataFrame`.

# %%
def the_first(DataFrame):
  a = DataFrame[:1]
  return a

the_first(df)
# Out:
#   show_id     type title director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 cast country       date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          description
# 0  In a future where the elite inhabit an island ...

# %% [markdown]
# 4.   Implementa una función que regrese el número de registros en el `DataFrame`.

# %%
def row_number(DataFrame):
  n = len(DataFrame)
  return n

row_number(df)
# Out:
# 7787

# %% [markdown]
# 5.   Implementa una función que despliega las películas con un `release_year` determminado.

# %%
def released_year(year):
  date = df[df.release_year ==year]
  return date

year_query = 2020
released_year(year_query)
# Out:
#      show_id     type                                title           director  \
# 0         s1  TV Show                                   3%                NaN
# 24       s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac                NaN
# 26       s27  TV Show                             (Un)Well                NaN
# 27       s28    Movie                               #Alive             Cho Il
# 29       s30  TV Show                             #blackAF                NaN
# ...      ...      ...                                  ...                ...
# 7725   s7726  TV Show                      You Cannot Hide                NaN
# 7734   s7735    Movie                      You've Got This  Salvador Espinosa
# 7738   s7739  TV Show                      Young Wallander                NaN
# 7741   s7742    Movie            Your Name Engraved Herein      Liu Kuang-hui
# 7744   s7745    Movie          Yours Sincerely, Kanan Gill       Neville Shah
#
# ...

# %% [markdown]
# 6.   Implementa una función que despliegue las películas que son de un país determinado.

# %%
def origin_country(country):
  origin = df[df.country == country]
  return origin

country_query = 'Mexico'
origin_country(country_query)
# Out:
#      show_id     type                                           title  \
# 1         s2    Movie                                            7:19
# 12       s13  TV Show                                            1994
# 292     s293    Movie                             Acapulco La vida va
# 370     s371    Movie                  Alan Saldaña: Mi vida de pobre
# 378     s379    Movie  Alex Fernández: The Best Comedian in the World
# ...      ...      ...                                             ...
# 7698   s7699  TV Show                                          Yankee
# 7725   s7726  TV Show                                 You Cannot Hide
# 7734   s7735    Movie                                 You've Got This
# 7773   s7774    Movie                                  Zoé: Panoramas
# 7779   s7780  TV Show                                       Zona Rosa
#
#                                    director  \
# 1                         Jorge Michel Grau
# ...

# %% [markdown]
# 7.   Crea un nuevo `DataFrame` que sólo contenga las columnas `type`, `title`, `country` y `release_year`.

# %%
df2 = pd.DataFrame(columns=('Type','Title','Country','Release_year'))
df2
# Out:
# Empty DataFrame
# Columns: [Type, Title, Country, Release_year]
# Index: []

# %% [markdown]
# 8.   Despliega, cuántos tipos de producciones (`type`) se hicieron por país determinado (`country`).

# %%
tipo = df.groupby(['type','country']).count()
tipo
# Out:
#                                                             show_id  title  \
# type    country
# Movie   Argentina                                                34     34
#         Argentina, Brazil, France, Poland, Germany, Den...        1      1
#         Argentina, Chile                                          1      1
#         Argentina, Chile, Peru                                    1      1
#         Argentina, France                                         1      1
# ...                                                             ...    ...
# TV Show United States, South Korea, China                         2      2
#         United States, Sweden                                     1      1
#         United States, United Kingdom                             7      7
#         United States, United Kingdom, Australia                  1      1
#         Uruguay, Germany                                          1      1
#
# ...

# %% [markdown]
# 9.   Implementa la función que genera el cuadrado de un número.

# %%
def square(x):
  cuadrado = x**2
  return cuadrado

# %% [markdown]
# 10.   Usando el método `apply`, genera el cuadrado de todos los valores del siguiente `DataFrame`.

# %%
df2 = pd.DataFrame({'A': [1, 2, 3, 5, 6], 'B': [10, 20, 30, 40, 50]})
df2
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 3  5  40
# 4  6  50
